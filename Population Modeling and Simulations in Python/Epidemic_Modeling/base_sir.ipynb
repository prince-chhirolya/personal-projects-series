# %% [markdown]
# # Task 11: Making an SIR Model

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %% [markdown]
# ## Defining helper functions for the simulation

# %%
def SIR_sim(N, sim_days, orig_infected, prob_infect, contact_with_people, inf_days):
    y0 = N-orig_infected, orig_infected, 0
    beta = prob_infect*contact_with_people
    gamma = 1.0 / inf_days
    R0 = beta/gamma
    t = np.linspace(0, sim_days-1, sim_days)
    sim_res = odeint(sir_step_ahead, y0, t, args=(N, beta, gamma))
    S, I, R = sim_res.T
    return S, I, R, R0


def sim_plot(S, I, R, R0):
    t = np.linspace(0, len(S), len(S))
    plt.title("SIR Simulation (R0= " + str(round(R0, 3)) + ")")
    plt.plot(t, S, label="Susceptible")
    plt.plot(t, I, label="Infected")
    plt.plot(t, R, label="Recovered")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Main simulation function

# %%
def sir_step_ahead(y, t, N, beta, gamma):
    S, I, R = y
    dsdt = -beta * I * (S / N)
    didt = beta * I * (S / N) - gamma * I
    drdt = gamma * I
    return dsdt, didt, drdt

# %% [markdown]
# ## Running the simulation and exploring the results

# %%
N, sim_days = 500, 100
orig_infected = 3
prob_infect = 0.15
contact_with_people = 5
inf_days = 7

S, I, R, R0 = SIR_sim(N, sim_days, orig_infected, prob_infect, contact_with_people, inf_days)
sim_plot(S, I, R, R0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 contact_with_people = 5
#       5 inf_days = 7
# ----> 7 S, I, R, R0 = SIR_sim(N, sim_days, orig_infected, prob_infect, contact_with_people, inf_days)
#       8 sim_plot(S, I, R, R0)
#
# NameError: name 'SIR_sim' is not defined
