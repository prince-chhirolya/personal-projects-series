# %% [markdown]
# # Develop a Chatbot Using Python, NLTK, and TensorFlow

# %%
# Run this cell so you do not see GPU availibility errors from tensorflow
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# ### Task 1: Import the Required Libraries

# %%
import json
import random
import pickle

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

import numpy as np
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, Embedding, LSTM

import matplotlib.pyplot as plt
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777823325.207321     266 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777823325.215106     266 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777823325.238334     266 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777823325.238382     266 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777823325.238385     266 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777823325.238388     266 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# ### Task 2: Load the Data

# %%
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True) 
nltk.download('wordnet', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('omw-1.4', quiet=True)

with open('/usercode/intents.json') as data:
    intents = json.loads(data.read())

# %% [markdown]
# ### Task 3: Tokenization

# %%
# Initialize necessary lists
words = []
classes = []
documents = []

# Iterate through intents 
for intent in intents['intents']:
    # Loop through each pattern in an intent
    for pattern in intent['patterns']:
        # Tokenize the pattern
        w = nltk.word_tokenize(pattern) 
        # Add tokens to the `words` list
        words.extend(w)
        # Store (tokenized words, intent tag)
        documents.append((w, intent['tag']))
        # Add unique intent tag to the list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %% [markdown]
# ### Task 4: Lemmatization

# %%
#  Initialize the WordNet Lemmatizer
lemmatizer = WordNetLemmatizer()
# List for ignored characters & Stopwords
ignore_words = ['?', '!', '.', ',']
stop_words = set(stopwords.words('english'))  # Add stopwords for better preprocessing

# Lemmatize and remove stopwords
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words and w.lower() not in stop_words]

# Remove duplicates & sort words and classes
words = sorted(set(words))
classes = sorted(set(classes))

# Save processed words
with open('/usercode/words.pkl', 'wb') as file:
    pickle.dump(words, file)

# Save processed classes
with open('/usercode/classes.pkl', 'wb') as file:
    pickle.dump(classes, file)

# %% [markdown]
# ### Task 5: Create Data for Training

# %%
# Create Data for Training
training = []
output_empty = [0] * len(classes)

# Iterate through the documents list
for doc in documents:
    bag = []
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in doc[0]] # lemmatize and lowercase each sentence
    bag = [1 if w in pattern_words else 0 for w in words] # Creates a list (bag) where 1 indicates the presence of a word and 0 means it's absent.
    # Create One-Hot Encoded Labels
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    # Add data to the training set
    training.append([bag, output_row])

# Shuffle and convert data to NumPy arrays
random.shuffle(training)
training = np.array(training, dtype='object')

# Extract features (`X_train`) and labels (`y_train`)
X_train = list(training[:, 0])
y_train = list(training[:, 1])

# Convert data to TensorFlow Dataset
X_train = np.array(X_train)
y_train = np.array(y_train)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Convert data to TensorFlow dataset for training
train_data = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1024).batch(32)

# %% [markdown]
# ### Task 6: Design the Model

# %%
# Initialize the Model
model = Sequential([
    Dense(256, input_shape=(len(X_train[0]),), activation='relu'), # input layer and first hidden layer
    Dropout(0.3), # first dropout layer
    Dense(128, activation='relu'), # second hidden layer
    Dropout(0.3), # second dropout layer
    Dense(64, activation='relu'), # third hidden layer
    # Output layer
    Dense(len(y_train[0]), activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Task 7: Train and Save the Model

# %%
# Compile the Model
model.compile(
            loss='categorical_crossentropy',
            optimizer=Adam(learning_rate=0.001), 
            metrics=['accuracy'])

# Train the Model
history = model.fit(
                    train_data, 
                    epochs=200, verbose=1,
                    validation_data=(X_val, y_val))

# Save the Model
model.save('/usercode/trained_model.keras')
# Out:
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 295ms/step - accuracy: 0.0697 - loss: 2.5759 - val_accuracy: 0.0769 - val_loss: 2.6040
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9768 - loss: 0.0291 - val_accuracy: 0.5385 - val_loss: 2.4519
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.5385 - val_loss: 2.4550
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9768 - loss: 0.0330 - val_accuracy: 0.5385 - val_loss: 2.4649
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9872 - loss: 0.0279 - val_accuracy: 0.5385 - val_loss: 2.4757
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9872 - loss: 0.0282 - val_accuracy: 0.5385 - val_loss: 2.4901
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9872 - loss: 0.0224 - val_accuracy: 0.4615 - val_loss: 2.5094
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9535 - loss: 0.0490 - val_accuracy: 0.4615 - val_loss: 2.5316
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 0.0277 - val_accuracy: 0.4615 - val_loss: 2.5758
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9768 - loss: 0.0574 - val_accuracy: 0.4615 - val_loss: 2.6097
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9535 - loss: 0.0680 - val_accuracy: 0.4615 - val_loss: 2.6406
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9872 - loss: 0.0234 - val_accuracy: 0.4615 - val_loss: 2.6677
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9535 - loss: 0.0567 - val_accuracy: 0.4615 - val_loss: 2.6941
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0239 - val_accuracy: 0.4615 - val_loss: 2.7129
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9768 - loss: 0.0406 - val_accuracy: 0.4615 - val_loss: 2.7272
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0231 - val_accuracy: 0.4615 - val_loss: 2.7382
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9872 - loss: 0.0325 - val_accuracy: 0.4615 - val_loss: 2.7497
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9872 - loss: 0.0316 - val_accuracy: 0.4615 - val_loss: 2.7587
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9535 - loss: 0.0540 - val_accuracy: 0.4615 - val_loss: 2.7613
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9768 - loss: 0.0559 - val_accuracy: 0.4615 - val_loss: 2.7604
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9872 - loss: 0.0199 - val_accuracy: 0.4615 - val_loss: 2.7654
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9872 - loss: 0.0441 - val_accuracy: 0.4615 - val_loss: 2.7614
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9768 - loss: 0.0356 - val_accuracy: 0.4615 - val_loss: 2.7503
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9768 - loss: 0.0556 - val_accuracy: 0.4615 - val_loss: 2.7433
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9535 - loss: 0.0627 - val_accuracy: 0.4615 - val_loss: 2.7337
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9768 - loss: 0.0344 - val_accuracy: 0.4615 - val_loss: 2.7276
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9768 - loss: 0.0387 - val_accuracy: 0.4615 - val_loss: 2.7076
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9768 - loss: 0.0488 - val_accuracy: 0.4615 - val_loss: 2.6919
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9768 - loss: 0.0453 - val_accuracy: 0.4615 - val_loss: 2.6825
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0210 - val_accuracy: 0.4615 - val_loss: 2.6723
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9768 - loss: 0.0312 - val_accuracy: 0.4615 - val_loss: 2.6626
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9768 - loss: 0.0364 - val_accuracy: 0.5385 - val_loss: 2.6513
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9872 - loss: 0.0363 - val_accuracy: 0.5385 - val_loss: 2.6377
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9768 - loss: 0.0330 - val_accuracy: 0.5385 - val_loss: 2.6369

# %% [markdown]
# ### Task 8: Print the Training Curves

# %%
plt.rcParams["figure.figsize"] = (12, 8)
epochs = np.arange(0, 200)
plt.style.use("ggplot")
plt.figure()
plt.plot(epochs, history.history["loss"], label="train_loss")
plt.plot(epochs, history.history["val_loss"], label="val_loss")
plt.plot(epochs, history.history['accuracy'], label="accuracy")
plt.plot(epochs, history.history["val_accuracy"], label="accuracy")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
